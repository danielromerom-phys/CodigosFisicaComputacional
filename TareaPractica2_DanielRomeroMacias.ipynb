# %% [markdown]
# # Tarea-Práctica 2.
#
# ## Fundamentos de programación para la Física Computacional

# %% [markdown]
# ## 1. La constante de Madelung
#
# En física de la materia condensada, la constante de Madelung da el potencial eléctrico total que siente un átomo en un sólido; y depende de las cargas de los otros átomos cercanos y de sus ubicaciones.
#
# Por ejemplo, el cristal de cloruro de sodio sólido (la sal de mesa), tiene átomos dispuestos en una red cúbica, con átomos de sodio y cloro alternados, teniendo los de sodio una carga positiva +e y los de cloro una negativa −e, (donde e es la carga del electrón). Si etiquetamos cada posición en la red con tres coordenadas enteras (i, j, k), entonces los átomos de sodio caen en posiciones donde i + j + k es par, y los átomos de cloro en posiciones donde i + j + k es impar.
#
# Consideremos un atomo de sodio en el origen, i.e. i = j = k = 0, y calculemos la constante de Madelung. Si el espaciado de los átomos en la red es a, entonces la distancia desde el origen al átomo en la posición (i, j, k) es:
#
# $\sqrt{(ia)^2+(ja)^2+(ka)^2} = a\sqrt{i^2+j^2+k^2}$
#
# y el potencial en el origen creado por tal atomo es:
#
# $V(i,j,k) = \pm \frac{e}{4 \pi \epsilon_{0} a \sqrt{i^2+j^2+k^2}}M $
#
# siendo $\epsilon_{0}$ la permitividad del vacío y el signo de la expresión se toma dependiendo de si i + j + k es par o impar. Así entonces, el potencial total que siente el atomo de sodio es la suma de esta cantidad sobre todos los demás átomos. Supongamos una caja cúbica alrededor del átomo de sodio en el origen, con L átomos en todas las direcciones, entonces:
#
# $V_{Total} = \sum_{i,j,k=-L}^{L}V(i,j,k) = \frac{e}{4 \pi \epsilon_{0} a}M $
#
# donde M es la constante de Madelung (al menos aproximadamente).
#
# Técnicamente, la constante de Madelung es el valor de M cuando L → ∞, pero se puede obtener una buena aproximación simplemente usando un valor grande de L.
#
# Escribe un programa para calcular e imprimir la constante de Madelung para el cloruro de sodio. Utiliza un valor de L tan grande como puedas, permitiendo que tu programa se ejecute en un tiempo razonable (un minuto o menos).

# %%
# Importación de bibliotecas
import numpy as np
import math as mt

# %%
# Función que arroja la constante de Madelung para una red de átomos de cloruro de sodio con un sodio centrado en el origen

def madelung(L):

    V = 0

    for i in range(-L, L+1, 1):
        for j in range(-L, L+1, 1):
            for k in range(-L, L+1, 1):
                
                if((i == 0) & (j == 0) & (k == 0)):
                    V = V # Caso cuando las tres variables espaciales son 0, para saltar el caso indefinido.
                elif((i+j+k)%2 == 0): 
                    V = 1/np.sqrt((i**2)+(j**2)+(k**2)) + V # Potencial en el origen creado por el átomo de sodio si i+j+k es par
                else:
                    V = -1/np.sqrt((i**2)+(j**2)+(k**2)) + V # Potencial en el origen creado por el átomo de sodio si i+j+k es impar

    M = V

    print("La constante de Madelung para el Cloruro de Sodio es de:", M)

# %%
madelung(100)
# Out:
# La constante de Madelung para el Cloruro de Sodio es de: -1.7418198158396654

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 2. La fórmula semiempírica de la masa (FSM)
#
# En física nuclear, la fórmula de Weizsaäcker (conocida también como fórmula semiempírica) sirve para evaluar la masa y otras propiedades de un núcleo atómico; y está basada parcialmente en mediciones empíricas. En particular la fórmula se usa para calcular la energía de enlace nuclear aproximada B, de un núcleo atómico con número atómico Z y número de masa A:
#
# $B = a_{1}A - a_{2}A^{2/3} - a_{3} \frac{Z^2}{A^{1/3}} - a_{4} \frac{(A-2Z)^{2}}{A} + \frac{a_5}{A^{1/2}}$
#
# donde, en unidades de millones de electron-volts, las constantes son $a_1$ = 15.8, $a_2$ =
# 18.3, $a_3$ = 0.714, $a_4$ = 23.2 y:
#
# $ a_5 =
#     \begin{cases}
#         \text{0,} &\quad\text{si A es impar} \\
#         \text{12.0,} &\quad\text{si A y Z son pares (ambos)} \\
#         \text{-12.0,} &\quad\text{si A es par y Z es impar} \\
#     \end{cases} $
#
# a) Escribe un programa que tome como entrada los valores de A y Z, e imprima la energía de enlace B para el átomo correspondiente. Usa tu programa para encontrar la energía de enlace de un átomo con A = 58 y Z = 28 (Hint: La respuesta correcta es alrededor de los 490 MeV).
#
# b) Modifica el programa del inciso anterior, para escribir una segunda versión que imprima no la energía de enlace total B, sino la energía de unión por nucleón, que es B/A.
#
# c) Escribe una tercera versión del programa para que tome como entrada solo un valor del número atómico Z y luego pase por todos los valores de A desde A = Z hasta A = 3Z, para encontrar el que tiene la mayor energía de enlace por nucleón. Este es el núcleo más estable con el número atómico dado. Haz que tu programa imprima el valor de A para este núcleo más estable y el valor de la energía de enlace por nucleón.
#
# d) Finalmente, escribe una cuarta versión del programa que, en lugar de tomar Z como entrada, se ejecute a través de todos los valores de Z de 1 a 100 e imprima el valor más estable de A para cada uno. ¿A qué valor de Z se produce la energía de enlace máxima por nucleón? (La respuesta correcta, en la vida real, es Z = 28, que corresponde al Níquel).

# %%
# Variables Globales

a1 = 15.8
a2 = 18.3
a3 = 0.714
a4 = 23.2

# %%
# Función para el inciso a) que toma de entrada valores de A y Z y retornna la energía de enlace B del átomo correspondiente.

def FSM_B_a(A, Z):
    
    if (A%2 != 0):
        a5 = 0
    elif (A%2 == 0 & Z%2 == 0):
        a5 = 12
    elif (A%2 == 0 & Z%2 != 0):
        a5 = -12

    B = (a1*A) - (a2*(A**(2/3))) - ((a3*(Z**2))/(A**(1/3))) - ((a4*((A-2*Z)**2))/A) + (a5/(A**(1/2)))

    print("La energía de enlace del átomo es de:", B, "MeV")

# %%
FSM_B_a(58, 28)
# Out:
# La energía de enlace del átomo es de: 497.5620206224374 MeV

# %%
# Función para el inciso b) que toma de entrada valores de A y Z y retornna la energía de unión por nucleón, que es B/A.

def FSM_B_b(A, Z):
    
    if (A%2 != 0):
        a5 = 0
    elif (A%2 == 0 & Z%2 == 0):
        a5 = 12
    elif (A%2 == 0 & Z%2 != 0):
        a5 = -12

    B = (a1*A) - (a2*(A**(2/3))) - ((a3*(Z**2))/(A**(1/3))) - ((a4*((A-2*Z)**2))/A) + (a5/(A**(1/2)))
    
    print("La energía de unión por nucleón del átomo es de: ", B/A, "MeV por nucleón.")

# %%
FSM_B_b(84, 28)
# Out:
# La energía de unión por nucleón del átomo es de:  7.537640039955393 MeV por nucleón.

# %%
# Función para el inciso c) que pasa por A=Z hasta A=3Z, compara el que tiene mayor energía de enlace por nucleón 
# y retorna el valor de A y la energía de enlace por nucleón B/A de dicho átomo con mayor energía de enlace por nucleón.

def FSM_B_c(Z):

    A2 = 0
    EUN2 = 0

    for j in range(1, 4, 1):
        
        A1 = j*Z
        
        if (A1%2 != 0):
            a5 = 0
        elif (A1%2 == 0 & Z%2 == 0):
            a5 = 12
        elif (A1%2 == 0 & Z%2 != 0):
            a5 = -12
        
        B = (a1*A1) - (a2*(A1**(2/3))) - ((a3*(Z**2))/(A1**(1/3))) - ((a4*((A1-2*Z)**2))/A1) + (a5/(A1**(1/2)))

        EUN1 = B/A1

        print("Iteración", j, ": Número de masa", A1, "y energía de enlace por nucleón", EUN1, "\n")
        
        if (EUN1 > EUN2):
            EUN = EUN1
            EUN2 = EUN1
            A = A1
            A2 = A1
        else:
            EUN = EUN2
            A = A2

    print("El número de masa del núcleo más estable del número atómico dado es de:", A)
    print("La energía de enlace por nucleón del núcleo más estable del número atómico dado es de:", EUN, "MeV por nucleón")

# %%
FSM_B_c(28)
# Out:
# Iteración 1 : Número de masa 28 y energía de enlace por nucleón -19.929209505462456
#
# Iteración 2 : Número de masa 56 y energía de enlace por nucleón 8.432655535147047
#
# Iteración 3 : Número de masa 84 y energía de enlace por nucleón 7.537640039955393
#
# El número de masa del núcleo más estable del número atómico dado es de: 56
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.432655535147047 MeV por nucleón

# %%
# Función para el inciso d) que toma de entrada el valor Z, pasa por Z=1 hasta Z=100, asigna valores de A=Z hasta A=3Z, compara el que tiene mayor 
# energía de enlace por nucleón y retorna el valor de A y la energía de enlace por nucleón B/A de dicho átomo con mayor energía de enlace por nucleón.

def FSM_B_d():

    Z2 = 0

    for z in range(1, 101, 1):
        
        A2 = 0
        EUN2 = 0

        for j in range(1, 4, 1):
            
            A1 = j*z
            
            if (A1%2 != 0):
                a5 = 0
            elif (A1%2 == 0 & z%2 == 0):
                a5 = 12
            elif (A1%2 == 0 & z%2 != 0):
                a5 = -12
            
            B = (a1*A1) - (a2*(A1**(2/3))) - ((a3*(z**2))/(A1**(1/3))) - ((a4*((A1-2*z)**2))/A1) + (a5/(A1**(1/2)))
    
            EUN1 = B/A1
        
            if (EUN1 > EUN2):
                EUN = EUN1
                EUN2 = EUN1
                A = A1
                A2 = A1
                Z = z
                Z2 = z
            else:
                EUN = EUN2
                A = A2
                Z = Z2

        print("Número atómico:", Z)
        print("El número de masa del núcleo más estable del número atómico dado es de:", A)
        print("La energía de enlace por nucleón del núcleo más estable del número atómico dado es de:", EUN, "MeV por nucleón \n")

# %%
FSM_B_d()
# Out:
# Número atómico: 1
# El número de masa del núcleo más estable del número atómico dado es de: 2
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 5.234569973833937 MeV por nucleón
#
# Número atómico: 2
# El número de masa del núcleo más estable del número atómico dado es de: 4
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 5.321930578649441 MeV por nucleón
#
# Número atómico: 3
# El número de masa del núcleo más estable del número atómico dado es de: 6
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 5.956224457871426 MeV por nucleón
#
# Número atómico: 4
# El número de masa del núcleo más estable del número atómico dado es de: 8
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.466330085889912 MeV por nucleón
#
# Número atómico: 5
# El número de masa del núcleo más estable del número atómico dado es de: 10
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.8568421469089404 MeV por nucleón
#
# Número atómico: 6
# El número de masa del núcleo más estable del número atómico dado es de: 12
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.159809204525104 MeV por nucleón
#
# Número atómico: 7
# El número de masa del núcleo más estable del número atómico dado es de: 14
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.399300030754118 MeV por nucleón
#
# Número atómico: 8
# El número de masa del núcleo más estable del número atómico dado es de: 16
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.591735836140193 MeV por nucleón
#
# Número atómico: 9
# El número de masa del núcleo más estable del número atómico dado es de: 18
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.748389006913737 MeV por nucleón
#
# Número atómico: 10
# El número de masa del núcleo más estable del número atómico dado es de: 20
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.877187191123463 MeV por nucleón
#
# Número atómico: 11
# El número de masa del núcleo más estable del número atómico dado es de: 22
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.983854464690984 MeV por nucleón
#
# Número atómico: 12
# El número de masa del núcleo más estable del número atómico dado es de: 24
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.072626562648601 MeV por nucleón
#
# Número atómico: 13
# El número de masa del núcleo más estable del número atómico dado es de: 26
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.14670739397895 MeV por nucleón
#
# Número atómico: 14
# El número de masa del núcleo más estable del número atómico dado es de: 28
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.208567763332145 MeV por nucleón
#
# Número atómico: 15
# El número de masa del núcleo más estable del número atómico dado es de: 30
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.260145876718632 MeV por nucleón
#
# Número atómico: 16
# El número de masa del núcleo más estable del número atómico dado es de: 32
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.302985198217316 MeV por nucleón
#
# Número atómico: 17
# El número de masa del núcleo más estable del número atómico dado es de: 34
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.338331348364699 MeV por nucleón
#
# Número atómico: 18
# El número de masa del núcleo más estable del número atómico dado es de: 36
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.36720159249431 MeV por nucleón
#
# Número atómico: 19
# El número de masa del núcleo más estable del número atómico dado es de: 38
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.3904355849674 MeV por nucleón
#
# Número atómico: 20
# El número de masa del núcleo más estable del número atómico dado es de: 40
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.408733038888997 MeV por nucleón
#
# Número atómico: 21
# El número de masa del núcleo más estable del número atómico dado es de: 42
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.422682109415975 MeV por nucleón
#
# Número atómico: 22
# El número de masa del núcleo más estable del número atómico dado es de: 44
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.432781071305767 MeV por nucleón
#
# Número atómico: 23
# El número de masa del núcleo más estable del número atómico dado es de: 46
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.439455080490596 MeV por nucleón
#
# Número atómico: 24
# El número de masa del núcleo más estable del número atómico dado es de: 48
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.443069281549286 MeV por nucleón
#
# Número atómico: 25
# El número de masa del núcleo más estable del número atómico dado es de: 50
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.443939164317321 MeV por nucleón
#
# Número atómico: 26
# El número de masa del núcleo más estable del número atómico dado es de: 52
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.44233882525383 MeV por nucleón
#
# Número atómico: 27
# El número de masa del núcleo más estable del número atómico dado es de: 54
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.438507615618514 MeV por nucleón
#
# Número atómico: 28
# El número de masa del núcleo más estable del número atómico dado es de: 56
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.432655535147047 MeV por nucleón
#
# Número atómico: 29
# El número de masa del núcleo más estable del número atómico dado es de: 58
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.42496764108743 MeV por nucleón
#
# Número atómico: 30
# El número de masa del núcleo más estable del número atómico dado es de: 60
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.415607677729058 MeV por nucleón
#
# Número atómico: 31
# El número de masa del núcleo más estable del número atómico dado es de: 62
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.404721083852166 MeV por nucleón
#
# Número atómico: 32
# El número de masa del núcleo más estable del número atómico dado es de: 64
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.392437500000002 MeV por nucleón
#
# Número atómico: 33
# El número de masa del núcleo más estable del número atómico dado es de: 66
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.378872870759881 MeV por nucleón
#
# Número atómico: 34
# El número de masa del núcleo más estable del número atómico dado es de: 68
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.364131216962928 MeV por nucleón
#
# Número atómico: 35
# El número de masa del núcleo más estable del número atómico dado es de: 70
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.34830613719051 MeV por nucleón
#
# Número atómico: 36
# El número de masa del núcleo más estable del número atómico dado es de: 72
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.3314820859969 MeV por nucleón
#
# Número atómico: 37
# El número de masa del núcleo más estable del número atómico dado es de: 74
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.313735466942566 MeV por nucleón
#
# Número atómico: 38
# El número de masa del núcleo más estable del número atómico dado es de: 76
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.295135571237012 MeV por nucleón
#
# Número atómico: 39
# El número de masa del núcleo más estable del número atómico dado es de: 78
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.275745387036471 MeV por nucleón
#
# Número atómico: 40
# El número de masa del núcleo más estable del número atómico dado es de: 80
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.25562229987603 MeV por nucleón
#
# Número atómico: 41
# El número de masa del núcleo más estable del número atómico dado es de: 82
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.23481870106956 MeV por nucleón
#
# Número atómico: 42
# El número de masa del núcleo más estable del número atómico dado es de: 84
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.213382517982605 MeV por nucleón
#
# Número atómico: 43
# El número de masa del núcleo más estable del número atómico dado es de: 86
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.191357677719015 MeV por nucleón
#
# Número atómico: 44
# El número de masa del núcleo más estable del número atómico dado es de: 88
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.168784513842347 MeV por nucleón
#
# Número atómico: 45
# El número de masa del núcleo más estable del número atómico dado es de: 90
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.145700124187274 MeV por nucleón
#
# Número atómico: 46
# El número de masa del núcleo más estable del número atómico dado es de: 92
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.122138686532766 MeV por nucleón
#
# Número atómico: 47
# El número de masa del núcleo más estable del número atómico dado es de: 94
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.098131737851734 MeV por nucleón
#
# Número atómico: 48
# El número de masa del núcleo más estable del número atómico dado es de: 96
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.073708421978127 MeV por nucleón
#
# Número atómico: 49
# El número de masa del núcleo más estable del número atómico dado es de: 98
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.048895709806569 MeV por nucleón
#
# Número atómico: 50
# El número de masa del núcleo más estable del número atómico dado es de: 100
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 8.02371859553474 MeV por nucleón
#
# Número atómico: 51
# El número de masa del núcleo más estable del número atómico dado es de: 102
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.998200271952399 MeV por nucleón
#
# Número atómico: 52
# El número de masa del núcleo más estable del número atómico dado es de: 104
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.972362287355745 MeV por nucleón
#
# Número atómico: 53
# El número de masa del núcleo más estable del número atómico dado es de: 106
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.946224686307504 MeV por nucleón
#
# Número atómico: 54
# El número de masa del núcleo más estable del número atómico dado es de: 108
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.91980613616007 MeV por nucleón
#
# Número atómico: 55
# El número de masa del núcleo más estable del número atómico dado es de: 110
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.8931240410019665 MeV por nucleón
#
# Número atómico: 56
# El número de masa del núcleo más estable del número atómico dado es de: 112
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.86619464446913 MeV por nucleón
#
# Número atómico: 57
# El número de masa del núcleo más estable del número atómico dado es de: 114
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.839033122675798 MeV por nucleón
#
# Número atómico: 58
# El número de masa del núcleo más estable del número atómico dado es de: 116
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.811653668360066 MeV por nucleón
#
# Número atómico: 59
# El número de masa del núcleo más estable del número atómico dado es de: 118
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.78406956720177 MeV por nucleón
#
# Número atómico: 60
# El número de masa del núcleo más estable del número atómico dado es de: 120
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.75629326715257 MeV por nucleón
#
# Número atómico: 61
# El número de masa del núcleo más estable del número atómico dado es de: 122
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.728336441516053 MeV por nucleón
#
# Número atómico: 62
# El número de masa del núcleo más estable del número atómico dado es de: 124
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.700210046427585 MeV por nucleón
#
# Número atómico: 63
# El número de masa del núcleo más estable del número atómico dado es de: 126
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.671924373307378 MeV por nucleón
#
# Número atómico: 64
# El número de masa del núcleo más estable del número atómico dado es de: 128
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.643489096793597 MeV por nucleón
#
# Número atómico: 65
# El número de masa del núcleo más estable del número atómico dado es de: 130
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.614913318604775 MeV por nucleón
#
# Número atómico: 66
# El número de masa del núcleo más estable del número atómico dado es de: 132
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.586205607730045 MeV por nucleón
#
# Número atómico: 67
# El número de masa del núcleo más estable del número atómico dado es de: 134
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.557374037301754 MeV por nucleón
#
# Número atómico: 68
# El número de masa del núcleo más estable del número atómico dado es de: 136
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.528426218466128 MeV por nucleón
#
# Número atómico: 69
# El número de masa del núcleo más estable del número atómico dado es de: 138
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.499369331533846 MeV por nucleón
#
# Número atómico: 70
# El número de masa del núcleo más estable del número atómico dado es de: 140
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.470210154662202 MeV por nucleón
#
# Número atómico: 71
# El número de masa del núcleo más estable del número atómico dado es de: 142
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.44095509029445 MeV por nucleón
#
# Número atómico: 72
# El número de masa del núcleo más estable del número atómico dado es de: 144
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.411610189558311 MeV por nucleón
#
# Número atómico: 73
# El número de masa del núcleo más estable del número atómico dado es de: 146
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.38218117480532 MeV por nucleón
#
# Número atómico: 74
# El número de masa del núcleo más estable del número atómico dado es de: 148
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.352673460454144 MeV por nucleón
#
# Número atómico: 75
# El número de masa del núcleo más estable del número atómico dado es de: 150
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.323092172284949 MeV por nucleón
#
# Número atómico: 76
# El número de masa del núcleo más estable del número atómico dado es de: 152
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.29344216531739 MeV por nucleón
#
# Número atómico: 77
# El número de masa del núcleo más estable del número atómico dado es de: 154
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.26372804039199 MeV por nucleón
#
# Número atómico: 78
# El número de masa del núcleo más estable del número atómico dado es de: 234
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.243334553887948 MeV por nucleón
#
# Número atómico: 79
# El número de masa del núcleo más estable del número atómico dado es de: 237
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.226872257929522 MeV por nucleón
#
# Número atómico: 80
# El número de masa del núcleo más estable del número atómico dado es de: 240
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.216887438148361 MeV por nucleón
#
# Número atómico: 81
# El número de masa del núcleo más estable del número atómico dado es de: 243
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.200349516332024 MeV por nucleón
#
# Número atómico: 82
# El número de masa del núcleo más estable del número atómico dado es de: 246
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.190055176937326 MeV por nucleón
#
# Número atómico: 83
# El número de masa del núcleo más estable del número atómico dado es de: 249
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.173450452704085 MeV por nucleón
#
# Número atómico: 84
# El número de masa del núcleo más estable del número atómico dado es de: 252
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.162869186595477 MeV por nucleón
#
# Número atómico: 85
# El número de masa del núcleo más estable del número atómico dado es de: 255
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.146205661949871 MeV por nucleón
#
# Número atómico: 86
# El número de masa del núcleo más estable del número atómico dado es de: 258
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.135358130820763 MeV por nucleón
#
# Número atómico: 87
# El número de masa del núcleo más estable del número atómico dado es de: 261
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.118643074277155 MeV por nucleón
#
# Número atómico: 88
# El número de masa del núcleo más estable del número atómico dado es de: 264
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.107548209038024 MeV por nucleón
#
# Número atómico: 89
# El número de masa del núcleo más estable del número atómico dado es de: 267
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.090788232634581 MeV por nucleón
#
# Número atómico: 90
# El número de masa del núcleo más estable del número atómico dado es de: 270
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.079463409272017 MeV por nucleón
#
# Número atómico: 91
# El número de masa del núcleo más estable del número atómico dado es de: 273
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.062664536204766 MeV por nucleón
#
# Número atómico: 92
# El número de masa del núcleo más estable del número atómico dado es de: 276
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.0511257305396935 MeV por nucleón
#
# Número atómico: 93
# El número de masa del núcleo más estable del número atómico dado es de: 279
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.034293454721383 MeV por nucleón
#
# Número atómico: 94
# El número de masa del núcleo más estable del número atómico dado es de: 282
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.022555378979696 MeV por nucleón
#
# Número atómico: 95
# El número de masa del núcleo más estable del número atómico dado es de: 285
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 7.005694717624511 MeV por nucleón
#
# Número atómico: 96
# El número de masa del núcleo más estable del número atómico dado es de: 288
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.993770941279936 MeV por nucleón
#
# Número atómico: 97
# El número de masa del núcleo más estable del número atómico dado es de: 291
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.9768864814463605 MeV por nucleón
#
# Número atómico: 98
# El número de masa del núcleo más estable del número atómico dado es de: 294
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.964789538420454 MeV por nucleón
#
# Número atómico: 99
# El número de masa del núcleo más estable del número atómico dado es de: 297
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.947885478304736 MeV por nucleón
#
# Número atómico: 100
# El número de masa del núcleo más estable del número atómico dado es de: 300
# La energía de enlace por nucleón del núcleo más estable del número atómico dado es de: 6.935626962297092 MeV por nucleón

# %% [markdown]
# El programa arroja que para Z = 25 se produce la energía de enlace máxima por nucleón, que corresponde con el Manganeso. Esto difiere en en tres posiciones atrás que el real, Z = 28 correspondiente al Níquel.

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 3. Coeficientes binomiales
#
# El coeficiente binomial $\binom{n}{k}$ es un número entero igual a:
#
# $\binom{n}{k} = \frac{n!}{k!(n-k)!} = \frac{n \times (n-1) \times (n-2) \times ... \times (n-k+1)}{1 \times 2 \times ... \times k}$
#
# donde $k \geq 1$, o bien $\binom{n}{0} = 1$ cuando $k = 0$.
#
# a) Utiliza esta fórmula para escribir una función llamada binomial(n,k) (o como tu quieras) que calcule el coeficiente binomial para un n y k dados. Asegurate de que tu función devuelva la respuesta en forma de un número entero (no flotante) y proporcione el valor correcto de 1 para el caso en que k = 0
#
# b) Usando tu función, escribe un programa que imprima las primeras 20 líneas del “triángulo de Pascal’’. La n-ésima línea del triángulo de Pascal contiene $n + 1$ números, que son los coeficientes $\binom{n}{0}$, $\binom{n}{1}$, y así sucesivamente hasta $\binom{n}{n}$. De tal manera que las primeras líneas son:
#
# $ 1 2 1 $
#
# $ 1 3 3 1 $
#
# $ 1 4 6 4 1 $
#
# c) La probabilidad de que para una moneda no sesgada, lanzada n veces, salga aguila k veces es:
#
# $p(k|n) = \frac{\binom{n}{k}}{2^{n}}$
#
# Escribe un programa para calcular:
#
# 1) La probabilidad total de que una moneda lanzada 100 veces, salga águila exactamente 60 veces.
# 2) La probabilidad de que salga águila 60 veces o más.

# %%
# Solución de 3. a): Función que calcula el coeficiente binomial

def binomial(n, k):

    if((k<0) or (n<0)):
        print("Introduzca valores permitidos: k>=0 y n>=0")
        binomial_coef = 0
    elif k>n:
        print("Introduzca valores permitidos: k>=0 y n>=0")
        binomial_coef = 0
    elif k == 0:
        binomial_coef = 1
    else: 
        binomial_coef = int(mt.factorial(n)/(mt.factorial(k)*mt.factorial(n-k)))
        
    return(binomial_coef)

# %%
binomial(2, 0)
# Out:
# 1

# %%
# Solución de 3. b): Programa que imprime las primeras 20 líneas del triángulo de Pascal

for i in range(1, 5, 1):
    for j in range(0, i+1, 1):
        bin_coef = binomial(i,j)
        print(bin_coef, end=" ")
    print("\n")
# Out:
# 1 1
#
# 1 2 1
#
# 1 3 3 1
#
# 1 4 6 4 1

# %%
# Solución de 3. c): 

# 1. Programa para calcular la probabilidad total de que una moneda lanzada 100 veces, salga aguila exactamente 60 veces

p_k_n_1 = binomial(100, 60)/(2**100)

print("La probabilidad de que en una moneda lanzada 100 veces salga águila 60 es de:", p_k_n_1)
# Out:
# La probabilidad de que en una moneda lanzada 100 veces salga águila 60 es de: 0.010843866711637987

# %%
# Solución de 3. c): 

# 2. Programa para calcular la probabilidad de que salga aguila 60 veces o más.

p_k_n_2 = 0

for k in range(60,101,1):
    p_k_n = binomial(100, k)/(2**100) + p_k_n

print("La probabilidad de que en una moneda lanzada 100 veces salga águila 60 veces o más es de:", p_k_n_2)
# Out:
# La probabilidad de que en una moneda lanzada 100 veces salga águila 60 veces o más es de: 0

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Números Primos
#
# Una manera no muy eficiente para calcular numeros primos, es comprobar si cada número es divisible por cualquier número menor que él. Sin embargo, es posible escribir un programa mucho mas rápido para números primos utilizando las siguientes observaciones:
#
# a) Un número n es primo si no tiene factores primos menores que n. Por lo tanto, solo necesitamos comprobar si es divisible por otros primos.
#
# b) Si un número $n$ no es primo, con un factor $r$, entonces $n = rs$, donde $s$ también es un factor. Si $r \gt \sqrt{n}$, entonces $n = rs \gt \sqrt{ns}$, lo que implica que $s \lt \sqrt{n}$. En otras palabras, cualquier número no primo debe tener factores, y por lo tanto también factores primos, menores o iguales a $sqrt{n}$. Por lo tanto, para determinar si un número es primo, debemos comprobar sus factores primos solo hasta
# $\sqrt{n}$ inclusive; si no hay ninguno, entonces el número es primo.
#
# c) Si encontramos incluso un solo factor primo menor que $\sqrt{n}$, sabemos que el número no es primo y, por lo tanto, no hay necesidad de comprobar más; podemos descartar este número y pasar a otro.
#
# Escribe un programa que encuentre todos los primos hasta diez mil.
#
# Crea una lista para almacenar los primos, que comience sólo con el número 2. Luego, para cada número $n$ del 3 al 10,000 comprueba si es divisible por alguno de los primos de la lista hasta $\sqrt{n}$. En cuanto encuentres un factor primo, puedes dejar de revisar los demás; pues ya sabes que n no es primo.
#
# Si no encuentras ningun factor primo $\sqrt{n}$ o menor, entonces $n$ es primo y debes anadirlo a la lista.
#
# Puedes imprimir la lista completa al final del programa o imprimir los numeros individuales a medida que los encuentras.
